# %% [markdown]
# # Обучение HRNet
# Загружаем необходимые библиотеки:

# %%
import warnings

from train import train

warnings.filterwarnings('ignore')

# %% [markdown]
# Обучаем модель:

# %%
train('config.py')
# Out:
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# => num_images: 10750
# => load 10533 samples
# 2023-03-28 21:47:47,008 - mmpose - INFO - Start running, host: Aleksei@DESKTOP-6FN7PTO, work_dir: C:\Users\Aleksei\course_ocr\task1\cropper\workdirs\hrnet_1
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!
# => Total boxes: 4250
# => Total boxes after filter low score@0.0: 4250
# => num_images: 4250
# => load 4250 samples
# 2023-03-28 21:47:47,009 - mmpose - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) EvalHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# ...
